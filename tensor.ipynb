# %%
import torch
import torchvision
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms

# Writer will output to ./runs/ directory by default
writer = SummaryWriter()

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
trainset = datasets.MNIST('mnist_train', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
model = torchvision.models.resnet50(False)
# Have ResNet model take in grayscale rather than RGB
model.conv1 = torch.nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
images, labels = next(iter(trainloader))

grid = torchvision.utils.make_grid(images)
writer.add_image('images', grid, 0)
writer.add_graph(model, images)
writer.close()
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to mnist_train/MNIST/raw/train-images-idx3-ubyte.gz
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_17118/750551403.py in <module>
#       8
#       9 transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
# ---> 10 trainset = datasets.MNIST('mnist_train', train=True, download=True, transform=transform)
#      11 trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
#      12 model = torchvision.models.resnet50(False)
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/torchvision/datasets/mnist.py in __init__(self, root, train, transform, target_transform, download)
#      77
#      78         if download:
# ---> 79             self.download()
#      80
#      81         if not self._check_exists():
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/torchvision/datasets/mnist.py in download(self)
#     144         for url, md5 in self.resources:
#     145             filename = url.rpartition('/')[2]
# --> 146             download_and_extract_archive(url, download_root=self.raw_folder, filename=filename, md5=md5)
#     147
#     148         # process and save as torch files
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/torchvision/datasets/utils.py in download_and_extract_archive(url, download_root, extract_root, filename, md5, remove_finished)
#     254         filename = os.path.basename(url)
#     255
# --> 256     download_url(url, download_root, filename, md5)
#     257
#     258     archive = os.path.join(download_root, filename)
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/torchvision/datasets/utils.py in download_url(url, root, filename, md5)
#      70             urllib.request.urlretrieve(
#      71                 url, fpath,
# ---> 72                 reporthook=gen_bar_updater()
#      73             )
#      74         except (urllib.error.URLError, IOError) as e:  # type: ignore[attr-defined]
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/torchvision/datasets/utils.py in gen_bar_updater()
#      13
#      14 def gen_bar_updater() -> Callable[[int, int, int], None]:
# ---> 15     pbar = tqdm(total=None)
#      16
#      17     def bar_update(count, block_size, total_size):
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/tqdm/notebook.py in __init__(self, *args, **kwargs)
#     238         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     239         total = self.total * unit_scale if self.total else self.total
# --> 240         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     241         self.container.pbar = self
#     242         if display_here:
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#     116         if IProgress is None:  # #187 #451 #558 #872
#     117             raise ImportError(
# --> 118                 "IProgress not found. Please update jupyter and ipywidgets."
#     119                 " See https://ipywidgets.readthedocs.io/en/stable"
#     120                 "/user_install.html")
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
from torch.utils.tensorboard import SummaryWriter
import numpy as np
import os
writer = SummaryWriter()

for n_iter in range(100):
    t= os.path.join('Loss','cane')
    writer.add_scalar(t, np.random.random(), n_iter)
    writer.add_scalar('Loss/test', np.random.random(), n_iter)
    writer.add_scalar('Accuracy/train', np.random.random(), n_iter)
    writer.add_scalar('Accuracy/test', np.random.random(), n_iter)

# %%
print('mi'.join('l'))
# Out:
# l

# %%
import numpy as np

res_32 = np.array([])
res_64 = np.array([])
res_128 = np.array([])
res_256 = np.array([])
res_loss = np.array([])
log_loss_dict = {'low':res_256,'medium':res_128,'high':res_64,'huge':res_32,'loss':res_loss}

# %%
log_vars = {'low':8,'medium':2,'high':3,'huge':4,'loss':5}

for log_var in log_vars:
    log = log_vars[log_var]
    print('log',log_var,'is : ',log)
    print(log_loss_dict)
    log_loss_dict[log_var] = np.append(log_loss_dict[log_var],log)
# Out:
# log low is :  8
# {'low': array([1., 1., 4., 8., 8., 8., 8.]), 'medium': array([2., 2., 2., 2., 2., 2., 2.]), 'high': array([3., 3., 3., 3., 3., 3., 3.]), 'huge': array([4., 4., 4., 4., 4., 4., 4.]), 'loss': array([5., 5., 5., 5., 5., 5., 5.])}
# log medium is :  2
# {'low': array([1., 1., 4., 8., 8., 8., 8., 8.]), 'medium': array([2., 2., 2., 2., 2., 2., 2.]), 'high': array([3., 3., 3., 3., 3., 3., 3.]), 'huge': array([4., 4., 4., 4., 4., 4., 4.]), 'loss': array([5., 5., 5., 5., 5., 5., 5.])}
# log high is :  3
# {'low': array([1., 1., 4., 8., 8., 8., 8., 8.]), 'medium': array([2., 2., 2., 2., 2., 2., 2., 2.]), 'high': array([3., 3., 3., 3., 3., 3., 3.]), 'huge': array([4., 4., 4., 4., 4., 4., 4.]), 'loss': array([5., 5., 5., 5., 5., 5., 5.])}
# log huge is :  4
# {'low': array([1., 1., 4., 8., 8., 8., 8., 8.]), 'medium': array([2., 2., 2., 2., 2., 2., 2., 2.]), 'high': array([3., 3., 3., 3., 3., 3., 3., 3.]), 'huge': array([4., 4., 4., 4., 4., 4., 4.]), 'loss': array([5., 5., 5., 5., 5., 5., 5.])}
# log loss is :  5
# {'low': array([1., 1., 4., 8., 8., 8., 8., 8.]), 'medium': array([2., 2., 2., 2., 2., 2., 2., 2.]), 'high': array([3., 3., 3., 3., 3., 3., 3., 3.]), 'huge': array([4., 4., 4., 4., 4., 4., 4., 4.]), 'loss': array([5., 5., 5., 5., 5., 5., 5.])}

# %%
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
writer = SummaryWriter('runs/MODEL_1_TRAINING{}'.format(timestamp))

# %%
from model import build_forecaster

model = build_forecaster(
        cfg.model, train_cfg=cfg.train_cfg, test_cfg=cfg.test_cfg)

# %%
import torch
model = torch.load('/home/fperacch/Forecaster/saved/model copy.pth')
model.eval()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipykernel_7310/3728117521.py in <module>
#       1 import torch
# ----> 2 model = torch.load('/home/fperacch/Forecaster/saved/model copy.pth')
#       3 model.eval()
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     592                     opened_file.seek(orig_position)
#     593                     return torch.jit.load(opened_file)
# --> 594                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     595         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     596
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#     851     unpickler = pickle_module.Unpickler(data_file, **pickle_load_args)
#     852     unpickler.persistent_load = persistent_load
# --> 853     result = unpickler.load()
#     854
#     855     torch._utils._validate_loaded_sparse_tensors()
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/mmcv/utils/config.py in __getattr__(self, name)
#     306
#     307     def __getattr__(self, name):
# --> 308         return getattr(self._cfg_dict, name)
#     309
#     310     def __getitem__(self, name):
#
# ... last 1 frames repeated, from the frame below ...
#
# ~/miniconda3/envs/efficientPS_env/lib/python3.7/site-packages/mmcv/utils/config.py in __getattr__(self, name)
#     306
#     307     def __getattr__(self, name):
# --> 308         return getattr(self._cfg_dict, name)
#     309
#     310     def __getitem__(self, name):
#
# RecursionError: maximum recursion depth exceeded

# %%
for log in log_loss_dict:
    print('log ', log)
    print(log_loss_dict[log])
    mean = np.mean(log_loss_dict[log])
    print('mean for ', log , 'is ',mean)
    t= os.path.join('Loss',str(log))
    writer.add_scalar(t,mean,1)
# Out:
# log  low
# [1. 1. 4. 8. 8. 8. 8. 8.]
# mean for  low is  5.75
# log  medium
# [2. 2. 2. 2. 2. 2. 2. 2.]
# mean for  medium is  2.0
# log  high
# [3. 3. 3. 3. 3. 3. 3. 3.]
# mean for  high is  3.0
# log  huge
# [4. 4. 4. 4. 4. 4. 4. 4.]
# mean for  huge is  4.0
# log  loss
# [5. 5. 5. 5. 5. 5. 5. 5.]
# mean for  loss is  5.0

# %%
import imageio
path_images = '/home/fperacch/Forecaster/tmpDir_GT/tmp'

files =[]
for image in os.listdir(path_images):
    files.append(image)

sorted_files =  sorted(files)

with imageio.get_writer('GT.gif', mode='I') as writer:
    for image in sorted_files:
        print(image)
        filepath = os.path.join(path_images,image)
        image = imageio.imread(filepath)
        writer.append_data(image)






path_images = '/home/fperacch/Forecaster/tmpDir_PRE/tmp'

files =[]
for image in os.listdir(path_images):
    files.append(image)

sorted_files =  sorted(files)

with imageio.get_writer('PREDICTED.gif', mode='I') as writer:
    for image in sorted_files:
        print(image)
        filepath = os.path.join(path_images,image)
        image = imageio.imread(filepath)
        writer.append_data(image)
# Out:
# 2011_09_26_drive_0002_sync0000000006_panoptic.png
# 2011_09_26_drive_0002_sync0000000007_panoptic.png
# 2011_09_26_drive_0002_sync0000000008_panoptic.png
# 2011_09_26_drive_0002_sync0000000009_panoptic.png
# 2011_09_26_drive_0002_sync0000000010_panoptic.png
# 2011_09_26_drive_0002_sync0000000011_panoptic.png
# 2011_09_26_drive_0002_sync0000000012_panoptic.png
# 2011_09_26_drive_0002_sync0000000013_panoptic.png
# 2011_09_26_drive_0002_sync0000000014_panoptic.png
# 2011_09_26_drive_0002_sync0000000015_panoptic.png
# 2011_09_26_drive_0002_sync0000000016_panoptic.png
# 2011_09_26_drive_0002_sync0000000017_panoptic.png
# 2011_09_26_drive_0005_sync0000000107_panoptic.png
# 2011_09_26_drive_0005_sync0000000108_panoptic.png
# 2011_09_26_drive_0005_sync0000000109_panoptic.png
# 2011_09_26_drive_0005_sync0000000110_panoptic.png
# 2011_09_26_drive_0005_sync0000000111_panoptic.png
# 2011_09_26_drive_0005_sync0000000112_panoptic.png
# 2011_09_26_drive_0005_sync0000000113_panoptic.png
# 2011_09_26_drive_0005_sync0000000114_panoptic.png
# 2011_09_26_drive_0005_sync0000000115_panoptic.png
# 2011_09_26_drive_0005_sync0000000116_panoptic.png
# 2011_09_26_drive_0005_sync0000000117_panoptic.png
# 2011_09_26_drive_0005_sync0000000118_panoptic.png
# 2011_09_26_drive_0005_sync0000000119_panoptic.png
# 2011_09_26_drive_0005_sync0000000120_panoptic.png
# 2011_09_26_drive_0005_sync0000000121_panoptic.png
# 2011_09_26_drive_0005_sync0000000122_panoptic.png
# 2011_09_26_drive_0005_sync0000000123_panoptic.png
# 2011_09_26_drive_0005_sync0000000124_panoptic.png
# 2011_09_26_drive_0005_sync0000000125_panoptic.png
# 2011_09_26_drive_0005_sync0000000126_panoptic.png
# 2011_09_26_drive_0005_sync0000000127_panoptic.png
# 2011_09_26_drive_0005_sync0000000128_panoptic.png
# 2011_09_26_drive_0005_sync0000000129_panoptic.png
# 2011_09_26_drive_0005_sync0000000130_panoptic.png
# 2011_09_26_drive_0005_sync0000000131_panoptic.png
# 2011_09_26_drive_0005_sync0000000132_panoptic.png
# 2011_09_26_drive_0005_sync0000000133_panoptic.png
# 2011_09_26_drive_0005_sync0000000134_panoptic.png
# 2011_09_26_drive_0005_sync0000000135_panoptic.png
# 2011_09_26_drive_0005_sync0000000136_panoptic.png
# 2011_09_26_drive_0005_sync0000000137_panoptic.png
# 2011_09_26_drive_0005_sync0000000138_panoptic.png
# 2011_09_26_drive_0005_sync0000000139_panoptic.png
# 2011_09_26_drive_0005_sync0000000140_panoptic.png
# 2011_09_26_drive_0005_sync0000000141_panoptic.png
# 2011_09_26_drive_0005_sync0000000142_panoptic.png
# 2011_09_26_drive_0005_sync0000000143_panoptic.png
# 2011_09_26_drive_0005_sync0000000144_panoptic.png
# 2011_09_26_drive_0005_sync0000000145_panoptic.png
# 2011_09_26_drive_0005_sync0000000146_panoptic.png
# 2011_09_26_drive_0005_sync0000000147_panoptic.png
# 2011_09_26_drive_0005_sync0000000148_panoptic.png
# 2011_09_26_drive_0005_sync0000000149_panoptic.png
# 2011_09_26_drive_0005_sync0000000150_panoptic.png
# 2011_09_26_drive_0005_sync0000000151_panoptic.png

# %%
import matplotlib.pyplot as plt







lr = 0.05

list = []
epochs = 100
position = range(epochs)
width = [5,12,21,40]
i = 0


for epoch in range(epochs):
    print('epoch',epoch)
    list.append(lr)
     
    jump = epoch % width[i]
    print('jump',jump)
    if ((epoch % width[i] == 0) and (epoch !=0)) :
        lr = lr *3
        i +=1
    
    lr = lr*0.86
    


plt.plot(position,list)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
# Out:
# epoch 0
# jump 0
# epoch 1
# jump 1
# epoch 2
# jump 2
# epoch 3
# jump 3
# epoch 4
# jump 4
# epoch 5
# jump 0
# epoch 6
# jump 6
# epoch 7
# jump 7
# epoch 8
# jump 8
# epoch 9
# jump 9
# epoch 10
# jump 10
# epoch 11
# jump 11
# epoch 12
# jump 0
# epoch 13
# jump 13
# epoch 14
# jump 14
# epoch 15
# jump 15
# epoch 16
# jump 16
# epoch 17
# jump 17
# epoch 18
# jump 18
# epoch 19
# jump 19
# epoch 20
# jump 20
# epoch 21
# jump 0
# epoch 22
# jump 22
# epoch 23
# jump 23
# epoch 24
# jump 24
# epoch 25
# jump 25
# epoch 26
# jump 26
# epoch 27
# jump 27
# epoch 28
# jump 28
# epoch 29
# jump 29
# epoch 30
# jump 30
# epoch 31
# jump 31
# epoch 32
# jump 32
# epoch 33
# jump 33
# epoch 34
# jump 34
# epoch 35
# jump 35
# epoch 36
# jump 36
# epoch 37
# jump 37
# epoch 38
# jump 38
# epoch 39
# jump 39
# epoch 40
# jump 0
# epoch 41
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1248/1010791777.py in <module>
#      20     list.append(lr)
#      21
# ---> 22     jump = epoch % width[i]
#      23     print('jump',jump)
#      24     if ((epoch % width[i] == 0) and (epoch !=0)) :
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt

lr = 0.05

list = []
epochs = 100
position = range(epochs)
i = 0


for epoch in range(epochs):
    print('epoch',epoch)
    list.append(lr)

    if ((epoch % 5 == 0) and (epoch !=0)) :
        lr = lr *1.6
        i +=1
    
    lr = lr*0.86
    


plt.plot(position,list)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
# Out:
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# epoch 21
# epoch 22
# epoch 23
# epoch 24
# epoch 25
# epoch 26
# epoch 27
# epoch 28
# epoch 29
# epoch 30
# epoch 31
# epoch 32
# epoch 33
# epoch 34
# epoch 35
# epoch 36
# epoch 37
# epoch 38
# epoch 39
# epoch 40
# epoch 41
# epoch 42
# epoch 43
# epoch 44
# epoch 45
# epoch 46
# epoch 47
# epoch 48
# epoch 49
# epoch 50
# epoch 51
# epoch 52
# epoch 53
# epoch 54
# epoch 55
# epoch 56
# epoch 57
# epoch 58
# epoch 59
# epoch 60
# epoch 61
# epoch 62
# epoch 63
# epoch 64
# epoch 65
# epoch 66
# epoch 67
# epoch 68
# epoch 69
# epoch 70
# epoch 71
# epoch 72
# epoch 73
# epoch 74
# epoch 75
# epoch 76
# epoch 77
# epoch 78
# epoch 79
# epoch 80
# epoch 81
# epoch 82
# epoch 83
# epoch 84
# epoch 85
# epoch 86
# epoch 87
# epoch 88
# epoch 89
# epoch 90
# epoch 91
# epoch 92
# epoch 93
# epoch 94
# epoch 95
# epoch 96
# epoch 97
# epoch 98
# epoch 99
# Text(0, 0.5, 'Position (km)')
